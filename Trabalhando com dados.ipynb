# %%
#bibliotecas
# !pip install pandas
# !pip install numpy

# %%
#importando biblioteca
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importando Base de dados

#variavel = pd.csv_read('nome.csv')

bdgeral=pd.read_csv('Salaries.csv',sep=',')

# %%
#Visão geral

bdgeral.head(148655)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#Quais colunas tem nesta base?
len(bdgeral.head().columns)
# Out:
# 13

# %%
#Qual é a coluna de salario base?
#R:BasePay
bdgeral.BasePay.tolist()
# Out:
# [167411.18,
#  155966.02,
#  212739.13,
#  77916.0,
#  134401.6,
#  118602.0,
#  92492.01,
#  256576.96,
#  176932.64,
#  285262.0,
#  194999.39,
#  99722.0,
#  294580.02,
#  271329.03,
#  174872.64,
#  198778.01,
#  268604.57,
#  140546.87,
#  168692.63,
#  257510.59,
#  257510.48,
#  257510.44,
#  140546.88,
#  168692.63,
#  140546.86,
#  256470.41,
#  92080.8,
#  168692.59,
#  261717.6,
#  246225.6,
#  234325.02,
#  254027.63,
#  248895.7,
#  104861.39,
#  177781.25,
#  101953.2,
#  245124.44,
#  110661.2,
#  132202.26,
#  147158.85,
#  168692.66,
#  168692.63,
#  218930.76,
#  123013.02,
#  196081.86,
#  249375.02,
#  168692.64,
#  248895.77,
#  233867.6,
#  137729.92,
#  168692.59,
#  246305.62,
#  140546.87,
#  140546.88,
#  140546.89,
#  226206.8,
#  240731.93,
#  217410.8,
#  115381.02,
#  214745.44,
#  123105.0,
#  102571.24,
#  140546.86,
#  168692.62,
#  148970.43,
#  185369.69,
#  177914.76,
#  139167.39,
#  122974.0,
#  115455.44,
#  220983.12,
#  92782.61,
#  95770.8,
# ...

# %%
#Qual é o salário médio?

SomaTotal = int(bdgeral.BasePay.sum())
Divisao = 5 

print('R$: ',SomaTotal/Divisao)
# Out:
# R$:  1963830214.6

# %%
#Qual é o salário máximo?

MaiorSalario = bdgeral['BasePay'].max()
print("R$: ", MaiorSalario)
# Out:
# R$:  319275.01

# %%
#Qual é o emprego do JOSEPH DRISCOLL? EmployeeName e JobTitle

bdgeral.loc[bdgeral['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
# Qual é o salário médio por ano?

Ano2011 = bdgeral.loc[bdgeral['Year']==2011]['BasePay'].sum()/12
Ano2012 = bdgeral.loc[bdgeral['Year']==2012]['BasePay'].sum()/12
Ano2013 = bdgeral.loc[bdgeral['Year']==2013]['BasePay'].sum()/12
Ano2014 = bdgeral.loc[bdgeral['Year']==2014]['BasePay'].sum()/12



print('A média do salario de 2011 é: R$: ',Ano2011)
print('A média do salario de 2011 é: R$: ',Ano2012)
print('A média do salario de 2011 é: R$: ',Ano2013)
print('A média do salario de 2011 é: R$: ',Ano2014)
# Out:
# A média do salario de 2011 é: R$:  191630515.97416666
# A média do salario de 2011 é: R$:  200486244.54333338
# A média do salario de 2011 é: R$:  214698395.67000005
# A média do salario de 2011 é: R$:  211447433.27833334

# %%
#Existe correlação entre ano e salário?
import matplotlib.pyplot as plt 
import numpy as np 
  
plt.figure() 
x1 = [2011, 2012, 2013, 2014] 
y1 = [191630515.97, 200486244.54, 214698395.67, 211447433.27] 
plt.plot(x1, y1, '-.') 
plt.show()
